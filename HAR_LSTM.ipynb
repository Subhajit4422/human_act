# %%
# Importing Libraries

# %%
import pandas as pd
import numpy as np

# %%
# Activities are the class labels
# It is a 6 class classification
ACTIVITIES = {
    0: 'WALKING',
    1: 'WALKING_UPSTAIRS',
    2: 'WALKING_DOWNSTAIRS',
    3: 'SITTING',
    4: 'STANDING',
    5: 'LAYING',
}

# Utility function to print the confusion matrix
def confusion_matrix(Y_true, Y_pred):
    Y_true = pd.Series([ACTIVITIES[y] for y in np.argmax(Y_true, axis=1)])
    Y_pred = pd.Series([ACTIVITIES[y] for y in np.argmax(Y_pred, axis=1)])

    return pd.crosstab(Y_true, Y_pred, rownames=['True'], colnames=['Pred'])

# %% [markdown]
# ### Data

# %% [markdown]
# # New Section

# %%
# Data directory
DATADIR = 'UCI_HAR_Dataset'

# %%
# Raw data signals
# Signals are .....................................from Accelerometer and Gyroscope
# The signals are in x,y,z directions
# Sensor signals are filtered to have only body acceleration
# excluding the acceleration due to gravity
# Triaxial acceleration from the accelerometer is total acceleration
SIGNALS = [
    "body_acc_x",
    "body_acc_y",
    "body_acc_z",
    "body_gyro_x",
    "body_gyro_y",
    "body_gyro_z",
    "total_acc_x",
    "total_acc_y",
    "total_acc_z"
]

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Utility function to read the data from csv file
def _read_csv(filename):
    return pd.read_csv(filename, delim_whitespace=True, header=None)

# Utility function to load the load
def load_signals(subset):
    signals_data = []

    for signal in SIGNALS:
        filename = f'/content/drive/MyDrive/Colab Notebooks/Real world case studies/Human Activity Recognition/UCI_HAR_dataset/{subset}/Inertial Signals/{signal}_{subset}.txt'
        signals_data.append(
            _read_csv(filename).to_numpy()
        )

    # Transpose is used to change the dimensionality of the output,
    # aggregating the signals by combination of sample/timestep.
    # Resultant shape is (7352 train/2947 test samples, 128 timesteps, 9 signals)
    return np.transpose(signals_data, (1, 2, 0))

# %%
def load_y(subset):
    """
    The objective that we are trying to predict is a integer, from 1 to 6,
    that represents a human activity. We return a binary representation of
    every sample objective as a 6 bits vector using One Hot Encoding
    (https://pandas.pydata.org/pandas-docs/stable/generated/pandas.get_dummies.html)
    """
    filename = f'/content/drive/MyDrive/Colab Notebooks/Real world case studies/Human Activity Recognition/UCI_HAR_dataset/{subset}/y_{subset}.txt'
    y = _read_csv(filename)[0]

    return pd.get_dummies(y).to_numpy()

# %%
def load_data():
    """
    Obtain the dataset from multiple files.
    Returns: X_train, X_test, y_train, y_test
    """
    X_train, X_test = load_signals('train'), load_signals('test')
    y_train, y_test = load_y('train'), load_y('test')

    return X_train, X_test, y_train, y_test

# %%
# Importing tensorflow
np.random.seed(42)
import tensorflow as tf
tf.random.set_seed(42)

# %%
# Configuring a session
session_conf = tf.compat.v1.ConfigProto(
    intra_op_parallelism_threads=1,
    inter_op_parallelism_threads=1
)

# %%
# Import Keras
from keras import backend as K
sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
K.set_session(sess)

# %%
# Importing libraries
from keras.models import Sequential
from keras.layers import LSTM
from keras.layers.core import Dense, Dropout

# %%
# Initializing parameters
epochs = 30
batch_size = 16
n_hidden = 32

# %%
# Utility function to count the number of classes
def _count_classes(y):
    return len(set([tuple(category) for category in y]))

# %%
# Loading the train and test data
X_train, X_test, Y_train, Y_test = load_data()

# %%
timesteps = len(X_train[0])
input_dim = len(X_train[0][0])
n_classes = _count_classes(Y_train)

print(timesteps)
print(input_dim)
print(len(X_train))
# Out:
# 128
# 9
# 7352

# %% [markdown]
# - Defining the Architecture of LSTM

# %%
# Initiliazing the sequential model
model = Sequential()
# Configuring the parameters
model.add(LSTM(n_hidden, input_shape=(timesteps, input_dim)))
# Adding a dropout layer
model.add(Dropout(0.5))
# Adding a dense output layer with sigmoid activation
model.add(Dense(n_classes, activation='sigmoid'))
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 32)                5376
#
#  dropout (Dropout)           (None, 32)                0
#
#  dense (Dense)               (None, 6)                 198
#
# =================================================================
# Total params: 5,574
# Trainable params: 5,574
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compiling the model
model.compile(loss='categorical_crossentropy',
              optimizer='rmsprop',
              metrics=['accuracy'])

# %%
# Training the model
model.fit(X_train,
          Y_train,
          batch_size=batch_size,
          validation_data=(X_test, Y_test),
          epochs=epochs)
# Out:
# Epoch 1/30
# 460/460 [==============================] - 41s 83ms/step - loss: 1.1827 - accuracy: 0.5150 - val_loss: 0.8376 - val_accuracy: 0.6858
# Epoch 2/30
# 460/460 [==============================] - 30s 65ms/step - loss: 0.7278 - accuracy: 0.6998 - val_loss: 0.6738 - val_accuracy: 0.7272
# Epoch 3/30
# 460/460 [==============================] - 30s 65ms/step - loss: 0.5948 - accuracy: 0.7773 - val_loss: 0.5978 - val_accuracy: 0.7950
# Epoch 4/30
# 460/460 [==============================] - 31s 68ms/step - loss: 0.4300 - accuracy: 0.8658 - val_loss: 0.5818 - val_accuracy: 0.8259
# Epoch 5/30
# 460/460 [==============================] - 31s 67ms/step - loss: 0.3520 - accuracy: 0.8965 - val_loss: 0.5559 - val_accuracy: 0.8320
# Epoch 6/30
# 460/460 [==============================] - 34s 74ms/step - loss: 0.2810 - accuracy: 0.9168 - val_loss: 0.4084 - val_accuracy: 0.8731
# Epoch 7/30
# 460/460 [==============================] - 30s 65ms/step - loss: 0.2343 - accuracy: 0.9259 - val_loss: 0.5739 - val_accuracy: 0.8446
# Epoch 8/30
# 460/460 [==============================] - 30s 66ms/step - loss: 0.2284 - accuracy: 0.9295 - val_loss: 0.3423 - val_accuracy: 0.8890
# Epoch 9/30
# 460/460 [==============================] - 31s 68ms/step - loss: 0.2040 - accuracy: 0.9343 - val_loss: 0.4786 - val_accuracy: 0.8673
# Epoch 10/30
# 460/460 [==============================] - 35s 76ms/step - loss: 0.1907 - accuracy: 0.9372 - val_loss: 0.4027 - val_accuracy: 0.8911
# Epoch 11/30
# 460/460 [==============================] - 30s 65ms/step - loss: 0.1771 - accuracy: 0.9366 - val_loss: 0.3580 - val_accuracy: 0.8870
# Epoch 12/30
# 460/460 [==============================] - 30s 65ms/step - loss: 0.1688 - accuracy: 0.9399 - val_loss: 0.4649 - val_accuracy: 0.8870
# Epoch 13/30
# 460/460 [==============================] - 31s 66ms/step - loss: 0.1745 - accuracy: 0.9427 - val_loss: 0.5142 - val_accuracy: 0.8907
# Epoch 14/30
# 460/460 [==============================] - 33s 71ms/step - loss: 0.1587 - accuracy: 0.9456 - val_loss: 0.4720 - val_accuracy: 0.8921
# Epoch 15/30
# 460/460 [==============================] - 30s 65ms/step - loss: 0.1641 - accuracy: 0.9438 - val_loss: 0.3708 - val_accuracy: 0.9040
# Epoch 16/30
# 460/460 [==============================] - 31s 68ms/step - loss: 0.1575 - accuracy: 0.9441 - val_loss: 0.5970 - val_accuracy: 0.8846
# Epoch 17/30
# 460/460 [==============================] - 30s 65ms/step - loss: 0.1540 - accuracy: 0.9465 - val_loss: 0.4821 - val_accuracy: 0.8792
# Epoch 18/30
# 460/460 [==============================] - 31s 67ms/step - loss: 0.1610 - accuracy: 0.9437 - val_loss: 0.4496 - val_accuracy: 0.8928
# Epoch 19/30
# 460/460 [==============================] - 30s 66ms/step - loss: 0.1566 - accuracy: 0.9442 - val_loss: 0.3763 - val_accuracy: 0.8935
# Epoch 20/30
# 460/460 [==============================] - 30s 65ms/step - loss: 0.1362 - accuracy: 0.9480 - val_loss: 0.3444 - val_accuracy: 0.9091
# Epoch 21/30
# 460/460 [==============================] - 30s 66ms/step - loss: 0.1458 - accuracy: 0.9444 - val_loss: 0.4472 - val_accuracy: 0.9002
# Epoch 22/30
# 460/460 [==============================] - 30s 65ms/step - loss: 0.1561 - accuracy: 0.9467 - val_loss: 0.3212 - val_accuracy: 0.9074
# Epoch 23/30
# 460/460 [==============================] - 30s 66ms/step - loss: 0.1383 - accuracy: 0.9495 - val_loss: 0.4209 - val_accuracy: 0.9077
# Epoch 24/30
# 460/460 [==============================] - 30s 66ms/step - loss: 0.1544 - accuracy: 0.9474 - val_loss: 0.4556 - val_accuracy: 0.9131
# Epoch 25/30
# 460/460 [==============================] - 32s 69ms/step - loss: 0.1491 - accuracy: 0.9480 - val_loss: 0.4015 - val_accuracy: 0.9101
# Epoch 26/30
# 460/460 [==============================] - 30s 66ms/step - loss: 0.1604 - accuracy: 0.9453 - val_loss: 0.6096 - val_accuracy: 0.8918
# Epoch 27/30
# 460/460 [==============================] - 30s 65ms/step - loss: 0.1400 - accuracy: 0.9478 - val_loss: 0.7312 - val_accuracy: 0.8758
# Epoch 28/30
# 460/460 [==============================] - 30s 65ms/step - loss: 0.1415 - accuracy: 0.9461 - val_loss: 0.4534 - val_accuracy: 0.8928
# Epoch 29/30
# 460/460 [==============================] - 31s 67ms/step - loss: 0.1421 - accuracy: 0.9465 - val_loss: 0.4586 - val_accuracy: 0.8901
# Epoch 30/30
# 460/460 [==============================] - 32s 69ms/step - loss: 0.1382 - accuracy: 0.9489 - val_loss: 0.6103 - val_accuracy: 0.8979

# %%
# Confusion Matrix
print(confusion_matrix(Y_test, model.predict(X_test)))
# Out:
# Pred                LAYING  SITTING  STANDING  WALKING  WALKING_DOWNSTAIRS  \
# True
# LAYING                 512        0        25        0                   0
# SITTING                  3      410        75        0                   0
# STANDING                 0       87       445        0                   0
# WALKING                  0        0         0      481                   2
# WALKING_DOWNSTAIRS       0        0         0        0                 382
# WALKING_UPSTAIRS         0        0         0        2                  18
#
# Pred                WALKING_UPSTAIRS
# True
# LAYING                             0
# SITTING                            3
# STANDING                           0
# WALKING                           13
# WALKING_DOWNSTAIRS                38
# WALKING_UPSTAIRS                 451

# %%
score = model.evaluate(X_test, Y_test)
# Out:
# 2947/2947 [==============================] - 4s 2ms/step

# %%
score
# Out:
# [0.3087582236972612, 0.9097387173396675]

# %% [markdown]
# - With a simple 2 layer architecture we got 90.09% accuracy and a loss of 0.30
# - We can further imporve the performace with Hyperparameter tuning
